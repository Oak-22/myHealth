# %%
CHECK = "\u2713"
HEAVY_CHECK = "\u2714"
CROSS = "\u2716"


print(f"{CHECK} Validation Success!")
print(f"{HEAVY_CHECK} Validation Success!")
print(f"{CROSS} Validation Failed! Please check pipeline integrity.")
# Out:
# ✓ Validation Success!
# ✔ Validation Success!
# ✖ Validation Failed! Please check pipeline integrity.
